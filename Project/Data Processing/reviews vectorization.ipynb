# %%
import os
import pandas as pd
import re
import string
from tqdm import tqdm
from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec
import logging
from wordcloud import WordCloud
import matplotlib.pyplot as plt

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
nltk.download('punkt')
nltk.download('stopwords')

pd.set_option('display.max_columns', None)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Karl
# [nltk_data]     Zhang\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Karl
# [nltk_data]     Zhang\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
directory = r"Wine Reviews/"

if_start = True

for file in os.listdir(directory):
    file_location = directory + str(file)
    if if_start:
        wine_df = pd.read_csv(file_location, encoding='latin-1')
        if_start = False
    else:
        append_df = pd.read_csv(file_location, encoding='latin-1', low_memory=False)  # set low_memory to False to make sure that the feature types don't change for each file
        wine_df = pd.concat([wine_df, append_df], axis=0)

wine_df.drop_duplicates(subset=['Name'], inplace=True)

food_df = pd.read_csv('food_reviews.csv')

# %% [markdown]
# <br>
# Invoke the function used in labs, we drop some useless elements that a website review may commonly have.

# %%
def clean_text(text):
    text = re.sub(r'<.*?>', ' ', text)                           # substitute HTML tags with spaces
    text = re.sub(r'@[\w_]+', ' ', text)                         # substitute mentions with spaces
    text = re.sub(r'http[s]?://\S+|www\.\S+', ' ', text)         # substitute URLs with spaces
    return text

# %%
wine_df['Description'] = wine_df['Description'].astype(str)
wine_df['Description'] = wine_df['Description'].apply(clean_text)

food_df['Text'] = food_df['Text'].astype(str)
food_df['Text'] = food_df['Text'].apply(clean_text)

# %% [markdown]
# <br>
# Then, we apply sentence tokenization to both wine and food reviews. Basically, we firstly combine all reviews into one string (corpus) and then apply sent_tokenize to tokenize the whole string into sentences. Run the process for both wine and food reviews.

# %%
wine_reviews_list = list(wine_df['Description'])
full_wine_reviews_corpus = ' '.join(wine_reviews_list)
wine_reviews_sentences = sent_tokenize(full_wine_reviews_corpus)

food_reviews_list = list(food_df['Text'])
full_food_reviews_corpus = ' '.join(food_reviews_list)
food_reviews_sentences = sent_tokenize(full_food_reviews_corpus)

# %% [markdown]
# <br>
# Examples of elements in the lists after sentence tokenization would be:

# %%
print(wine_reviews_sentences[:2])
print('')
print(food_reviews_sentences[:2])
# Out:
# ["Made in partnership with Alpha Omega Winery's Jean Hoefliger, this famous namesake wine embraces the fullness that is Napa Valley concentration and sunny richness, showing baked plum, cinnamon and generous tannin and oak.", 'The backbone is plush and lush in texture, evolving as it opens in the glass.']
#
# ['I have bought several of the Vitality canned dog food products and have found them all to be of good quality.', 'The product looks more like a stew than a processed meat and it smells better.']

# %% [markdown]
# <br>
# Now we normalize each sentence in wine_reviews_sentences and food_reviews_sentences. Basically, this means to tokenize each sentence in two sentence lists into lists of words. Notice that we remove English stopwords, punctuations, use SnowballStemmer for stemming, and convert to lower-case.

# %%
stop_words = set(stopwords.words('english'))
punctuation_table = str.maketrans({key: None for key in string.punctuation})  # a table for removing punctuations
sno = SnowballStemmer('english')

def normalize_text(raw_text):
    try:
        word_list = word_tokenize(raw_text)
        normalized_sentence = []
        for w in word_list:
            try:
                w = str(w)
                lower_case_word = str.lower(w)
                stemmed_word = sno.stem(lower_case_word)  # convert all words to their stems
                no_punctuation = stemmed_word.translate(punctuation_table)  # remove punctuations
                if len(no_punctuation) > 1 and no_punctuation not in stop_words:  # remove letters and stop words
                    normalized_sentence.append(no_punctuation)
            except:
                continue
        return normalized_sentence
    except:
        return ''

# %%
normalized_wine_reviews_sentences = []
for sentence in tqdm(wine_reviews_sentences, desc="Processing Wine Reviews"):
    normalized_text = normalize_text(sentence)
    normalized_wine_reviews_sentences.append(normalized_text)

normalized_food_reviews_sentences = []
for sentence in tqdm(food_reviews_sentences, desc="Processing Food Reviews"):
    normalized_text = normalize_text(sentence)
    normalized_food_reviews_sentences.append(normalized_text)
# Out:
# Processing Wine Reviews: 100%|██████████| 401049/401049 [02:42<00:00, 2466.37it/s]
# Processing Food Reviews: 100%|██████████| 3052482/3052482 [20:08<00:00, 2525.69it/s]

# %% [markdown]
# <br>
# Examples of elements in the lists after word tokenization would be:

# %%
print(normalized_wine_reviews_sentences[:2])
print('')
print(normalized_food_reviews_sentences[:2])
# Out:
# [['made', 'partnership', 'alpha', 'omega', 'wineri', 'jean', 'hoeflig', 'famous', 'namesak', 'wine', 'embrac', 'full', 'napa', 'valley', 'concentr', 'sunni', 'rich', 'show', 'bake', 'plum', 'cinnamon', 'generous', 'tannin', 'oak'], ['backbon', 'plush', 'lush', 'textur', 'evolv', 'open', 'glass']]
#
# [['bought', 'sever', 'vital', 'dog', 'food', 'product', 'found', 'good', 'qualiti'], ['product', 'look', 'like', 'stew', 'process', 'meat', 'smell', 'better']]

# %% [markdown]
# <br>
# Since not all of the terms are single words, we extract 2-gram phrases that exist more than 100 times and 3-gram phrases that exist more than 50 times through Phrases. Besides, we save the 3-gram Phrases models for both wine and food.

# %%
wine_bigram_model = Phrases(normalized_wine_reviews_sentences, min_count=100)
wine_bigrams = [wine_bigram_model[line] for line in normalized_wine_reviews_sentences]
wine_trigram_model = Phrases(wine_bigrams, min_count=50)
phrased_wine_sentences = [wine_trigram_model[line] for line in wine_bigrams]
wine_trigram_model.save('wine_trigram_model.pkl')

food_bigram_model = Phrases(normalized_food_reviews_sentences, min_count=100)
food_bigrams = [food_bigram_model[line] for line in normalized_food_reviews_sentences]
food_trigram_model = Phrases(food_bigrams, min_count=50)
phrased_food_sentences = [food_trigram_model[line] for line in food_bigrams]
food_trigram_model.save('food_trigram_model.pkl')

# %% [markdown]
# <br>
# Examples of elements in the lists after word phrasing would be:

# %%
print(phrased_wine_sentences[3:5])
print('')
print(phrased_food_sentences[220:222])
# Out:
# [['cabernet_sauvignon', 'esteem', 'cold_creek', 'vineyard', 'make', 'backbon', 'wine'], ['intox', 'aroma', 'assort', 'dri', 'herb', 'graphit', 'spice', 'tea', 'leaf', 'coffe', 'black', 'cherri', 'follow', 'tight_wound', 'dark', 'fruit', 'flavor']]
#
# [['roast', 'home', 'stovetop', 'popcorn_popper', 'outsid', 'cours'], ['bean', 'coffe', 'bean', 'direct', 'green', 'mexican', 'altura', 'seem', 'wellsuit', 'method']]

# %% [markdown]
# <br>
# Now it's time for some visualization. The code of wordcloud plots should be something like below. See more in the visualization scripts.

# %%
# font_path = "./Roboto/Roboto-Black.ttf"

# all_words_wine = [word for sublist in phrased_wine_sentences for word in sublist]
# wordcloud_wine = WordCloud(width=400, height=200, font_path=font_path).generate(' '.join(all_words_wine))

# all_words_food = [word for sublist in phrased_food_sentences for word in sublist]
# wordcloud_food = WordCloud(width=400, height=200, font_path=font_path).generate(' '.join(all_words_food))

# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.imshow(wordcloud_wine, interpolation="bilinear")
# plt.axis('off')
# plt.title("Word Cloud for Wine Reviews")

# plt.subplot(1, 2, 2)
# plt.imshow(wordcloud_food, interpolation="bilinear")
# plt.axis('off')
# plt.title("Word Cloud for Food Reviews")

# plt.show()

# %%
# data = phrased_food_sentences

# with open('phrased_food_sentences.txt', 'w', encoding='utf-8') as file:
#     for item in data:
#         line = ' '.join(item) 
#         file.write(line + '\n')

# %% [markdown]
# <br>
# After that, apply a descriptor mapping process for the wine reviews with resources in descriptor_mapping.csv. The mapping csv file maps a raw descriptor that could be in a review to a detailed descriptor (level 3) with a detailed term (level 2), a raw term (level 1), and a type of the term (type).

# %%
descriptor_mapping = pd.read_csv('descriptor_mapping.csv', encoding='latin1').set_index('raw descriptor')

def return_mapped_descriptor(word, mapping):
    if word in list(mapping.index):
        normalized_word = mapping.at[word, 'level_3']
        return normalized_word
    else:
        return word

# %%
descriptor_mapping.head(5)
# Out:
#                     level_3      level_2 level_1      type
# raw descriptor
# abras              abrasive  high_tannin  tannin  nonaroma
# acacia               acacia      flowery  flower     aroma
# acacia_flower        acacia      flowery  flower     aroma
# aciddriven      acid_driven    high_acid    acid  nonaroma
# aggress          aggressive    high_acid    acid  nonaroma

# %%
normalized_wine_sentences = []
for sentence in phrased_wine_sentences:
    normalized_wine_sentence = []
    for word in sentence:
        normalized_word = return_mapped_descriptor(word, descriptor_mapping)
        normalized_wine_sentence.append(str(normalized_word))
    normalized_wine_sentences.append(normalized_wine_sentence)

# %%
normalized_wine_sentences[1:3]

# data = normalized_wine_sentences

# with open('normalized_wine_sentences(mapped).txt', 'w', encoding='utf-8') as file:
#     for item in data:
#         line = ' '.join(item) 
#         file.write(line + '\n')
# Out:
# [['backbon', 'plush', 'lush', 'textur', 'evolv', 'open', 'glass'],
#  ['enjoy', 'good', 'time', 'show', 'best', '2024â\x80\x932034']]

# %% [markdown]
# <br>
# Next, apply the same process for food reviews, but without normalizing the nonaroma descriptors.

# %%
aroma_descriptor_mapping = descriptor_mapping.loc[descriptor_mapping['type'] == 'aroma']

normalized_food_sentences = []
for sentence in tqdm(phrased_food_sentences, desc="Processing Phrased Food Sentences"):
    normalized_food_sentence = []
    for word in sentence:
        normalized_word = return_mapped_descriptor(word, aroma_descriptor_mapping)
        normalized_food_sentence.append(str(normalized_word))
    normalized_food_sentences.append(normalized_food_sentence)
# Out:
# Processing Phrased Food Sentences: 100%|██████████| 3052482/3052482 [33:32<00:00, 1516.55it/s]

# %%
normalized_food_sentences[1:3]

# data = normalized_food_sentences

# with open('normalized_food_sentences(mapped).txt', 'w', encoding='utf-8') as file:
#     for item in data:
#         line = ' '.join(item) 
#         file.write(line + '\n')
# Out:
# [['product', 'look', 'like', 'stew', 'process', 'meat', 'smell', 'better'],
#  ['labrador', 'finicki', 'appreci', 'product', 'better']]

# %% [markdown]
# <br>
# After series of data cleaning and descriptor mapping for both wine and food reviews, now combine them together. For convenience, we save the total normalized sentences <font color="red">(very important!)</font>

# %%
normalized_sentences = normalized_wine_sentences + normalized_food_sentences

# %%
# data = normalized_sentences

# with open('final_normalized_sentences.txt', 'w', encoding='utf-8') as file:
#     for item in data:
#         line = ' '.join(item) 
#         file.write(line + '\n')

# %% [markdown]
# <br>
# Now it's time to do vectorization.

# %%
logging.basicConfig(format="%(levelname)s - %(message)s", level=logging.INFO)

word2vec_model = Word2Vec(normalized_sentences, vector_size=300, min_count=8, epochs=15)
word2vec_model.save("word2vec.model")
# Out:
# INFO - collecting all words and their counts
# INFO - PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO - PROGRESS: at sentence #10000, processed 68205 words, keeping 3762 word types
# INFO - PROGRESS: at sentence #20000, processed 136181 words, keeping 5491 word types
# INFO - PROGRESS: at sentence #30000, processed 206028 words, keeping 6904 word types
# INFO - PROGRESS: at sentence #40000, processed 276062 words, keeping 8151 word types
# INFO - PROGRESS: at sentence #50000, processed 362817 words, keeping 10261 word types
# INFO - PROGRESS: at sentence #60000, processed 459662 words, keeping 11847 word types
# INFO - PROGRESS: at sentence #70000, processed 556828 words, keeping 13314 word types
# INFO - PROGRESS: at sentence #80000, processed 644147 words, keeping 14841 word types
# INFO - PROGRESS: at sentence #90000, processed 731193 words, keeping 16402 word types
# INFO - PROGRESS: at sentence #100000, processed 820799 words, keeping 17596 word types
# INFO - PROGRESS: at sentence #110000, processed 906427 words, keeping 18679 word types
# INFO - PROGRESS: at sentence #120000, processed 988789 words, keeping 19770 word types
# INFO - PROGRESS: at sentence #130000, processed 1067691 words, keeping 20655 word types
# INFO - PROGRESS: at sentence #140000, processed 1147875 words, keeping 21646 word types
# INFO - PROGRESS: at sentence #150000, processed 1235893 words, keeping 22181 word types
# INFO - PROGRESS: at sentence #160000, processed 1319327 words, keeping 22890 word types
# INFO - PROGRESS: at sentence #170000, processed 1409147 words, keeping 23574 word types
# INFO - PROGRESS: at sentence #180000, processed 1491942 words, keeping 24021 word types
# INFO - PROGRESS: at sentence #190000, processed 1579677 words, keeping 24771 word types
# INFO - PROGRESS: at sentence #200000, processed 1670261 words, keeping 25728 word types
# INFO - PROGRESS: at sentence #210000, processed 1763884 words, keeping 26607 word types
# INFO - PROGRESS: at sentence #220000, processed 1859067 words, keeping 27454 word types
# INFO - PROGRESS: at sentence #230000, processed 1949801 words, keeping 28326 word types
# INFO - PROGRESS: at sentence #240000, processed 2037679 words, keeping 29255 word types
# INFO - PROGRESS: at sentence #250000, processed 2126022 words, keeping 29877 word types
# INFO - PROGRESS: at sentence #260000, processed 2219000 words, keeping 30338 word types
# INFO - PROGRESS: at sentence #270000, processed 2309231 words, keeping 31034 word types
# INFO - PROGRESS: at sentence #280000, processed 2397124 words, keeping 32230 word types
# INFO - PROGRESS: at sentence #290000, processed 2479141 words, keeping 32857 word types
# INFO - PROGRESS: at sentence #300000, processed 2569432 words, keeping 33664 word types
# INFO - PROGRESS: at sentence #310000, processed 2653991 words, keeping 34415 word types
# INFO - PROGRESS: at sentence #320000, processed 2737934 words, keeping 34952 word types
# INFO - PROGRESS: at sentence #330000, processed 2823686 words, keeping 35498 word types
# INFO - PROGRESS: at sentence #340000, processed 2914196 words, keeping 36247 word types
# INFO - PROGRESS: at sentence #350000, processed 3009416 words, keeping 37082 word types
# INFO - PROGRESS: at sentence #360000, processed 3094977 words, keeping 37810 word types
# INFO - PROGRESS: at sentence #370000, processed 3178429 words, keeping 38203 word types
# INFO - PROGRESS: at sentence #380000, processed 3262080 words, keeping 38899 word types
# INFO - PROGRESS: at sentence #390000, processed 3340492 words, keeping 39490 word types
# INFO - PROGRESS: at sentence #400000, processed 3435303 words, keeping 40258 word types
# INFO - PROGRESS: at sentence #410000, processed 3506652 words, keeping 43544 word types
# INFO - PROGRESS: at sentence #420000, processed 3577369 words, keeping 45726 word types
# INFO - PROGRESS: at sentence #430000, processed 3649704 words, keeping 47695 word types
# INFO - PROGRESS: at sentence #440000, processed 3722385 words, keeping 49253 word types
# INFO - PROGRESS: at sentence #450000, processed 3793601 words, keeping 50466 word types
# INFO - PROGRESS: at sentence #460000, processed 3864370 words, keeping 51894 word types
# INFO - PROGRESS: at sentence #470000, processed 3936657 words, keeping 53200 word types
# INFO - PROGRESS: at sentence #480000, processed 4009827 words, keeping 54397 word types
# INFO - PROGRESS: at sentence #490000, processed 4081826 words, keeping 55354 word types
# INFO - PROGRESS: at sentence #500000, processed 4152595 words, keeping 56401 word types
# INFO - PROGRESS: at sentence #510000, processed 4227275 words, keeping 57464 word types
# INFO - PROGRESS: at sentence #520000, processed 4302944 words, keeping 58473 word types
# INFO - PROGRESS: at sentence #530000, processed 4378163 words, keeping 59312 word types
# INFO - PROGRESS: at sentence #540000, processed 4448184 words, keeping 60084 word types
# INFO - PROGRESS: at sentence #550000, processed 4519636 words, keeping 60979 word types
# INFO - PROGRESS: at sentence #560000, processed 4589229 words, keeping 61723 word types
# INFO - PROGRESS: at sentence #570000, processed 4659466 words, keeping 62274 word types
# INFO - PROGRESS: at sentence #580000, processed 4729537 words, keeping 62978 word types
# INFO - PROGRESS: at sentence #590000, processed 4798919 words, keeping 63886 word types
# INFO - PROGRESS: at sentence #600000, processed 4869729 words, keeping 64695 word types
# INFO - PROGRESS: at sentence #610000, processed 4943050 words, keeping 65597 word types
# INFO - PROGRESS: at sentence #620000, processed 5013928 words, keeping 66289 word types
# INFO - PROGRESS: at sentence #630000, processed 5089096 words, keeping 67129 word types
# INFO - PROGRESS: at sentence #640000, processed 5160243 words, keeping 67795 word types
# INFO - PROGRESS: at sentence #650000, processed 5233143 words, keeping 68377 word types
# INFO - PROGRESS: at sentence #660000, processed 5303615 words, keeping 69031 word types
# INFO - PROGRESS: at sentence #670000, processed 5373941 words, keeping 69658 word types
# INFO - PROGRESS: at sentence #680000, processed 5446203 words, keeping 70390 word types
# INFO - PROGRESS: at sentence #690000, processed 5516290 words, keeping 71142 word types
# INFO - PROGRESS: at sentence #700000, processed 5591036 words, keeping 71855 word types
# INFO - PROGRESS: at sentence #710000, processed 5658509 words, keeping 72383 word types
# INFO - PROGRESS: at sentence #720000, processed 5731467 words, keeping 73096 word types
# INFO - PROGRESS: at sentence #730000, processed 5806434 words, keeping 73915 word types
# INFO - PROGRESS: at sentence #740000, processed 5879687 words, keeping 74496 word types
# INFO - PROGRESS: at sentence #750000, processed 5953668 words, keeping 75086 word types
# INFO - PROGRESS: at sentence #760000, processed 6027769 words, keeping 75754 word types
# INFO - PROGRESS: at sentence #770000, processed 6099383 words, keeping 76216 word types
# INFO - PROGRESS: at sentence #780000, processed 6172526 words, keeping 76745 word types
# INFO - PROGRESS: at sentence #790000, processed 6247065 words, keeping 77412 word types
# INFO - PROGRESS: at sentence #800000, processed 6318367 words, keeping 78110 word types
# INFO - PROGRESS: at sentence #810000, processed 6390786 words, keeping 78596 word types
# INFO - PROGRESS: at sentence #820000, processed 6464128 words, keeping 79195 word types
# INFO - PROGRESS: at sentence #830000, processed 6535211 words, keeping 79604 word types
# INFO - PROGRESS: at sentence #840000, processed 6606662 words, keeping 80200 word types
# INFO - PROGRESS: at sentence #850000, processed 6677447 words, keeping 80761 word types
# INFO - PROGRESS: at sentence #860000, processed 6748741 words, keeping 81344 word types
# INFO - PROGRESS: at sentence #870000, processed 6817945 words, keeping 81896 word types
# INFO - PROGRESS: at sentence #880000, processed 6891930 words, keeping 82376 word types
# INFO - PROGRESS: at sentence #890000, processed 6971242 words, keeping 83039 word types
# INFO - PROGRESS: at sentence #900000, processed 7043309 words, keeping 83613 word types
# INFO - PROGRESS: at sentence #910000, processed 7116326 words, keeping 84196 word types
# INFO - PROGRESS: at sentence #920000, processed 7187696 words, keeping 84708 word types
# INFO - PROGRESS: at sentence #930000, processed 7257954 words, keeping 85185 word types
# INFO - PROGRESS: at sentence #940000, processed 7329780 words, keeping 85533 word types
# INFO - PROGRESS: at sentence #950000, processed 7401832 words, keeping 86063 word types
# INFO - PROGRESS: at sentence #960000, processed 7473185 words, keeping 86484 word types
# INFO - PROGRESS: at sentence #970000, processed 7543186 words, keeping 86868 word types
# INFO - PROGRESS: at sentence #980000, processed 7613796 words, keeping 87517 word types
# INFO - PROGRESS: at sentence #990000, processed 7684572 words, keeping 88092 word types
# INFO - PROGRESS: at sentence #1000000, processed 7757133 words, keeping 88507 word types
# INFO - PROGRESS: at sentence #1010000, processed 7831011 words, keeping 89114 word types
# INFO - PROGRESS: at sentence #1020000, processed 7901999 words, keeping 89545 word types
# INFO - PROGRESS: at sentence #1030000, processed 7974272 words, keeping 90007 word types
# INFO - PROGRESS: at sentence #1040000, processed 8047599 words, keeping 90317 word types
# INFO - PROGRESS: at sentence #1050000, processed 8121319 words, keeping 90958 word types
# INFO - PROGRESS: at sentence #1060000, processed 8192566 words, keeping 91621 word types
# INFO - PROGRESS: at sentence #1070000, processed 8264438 words, keeping 92214 word types
# INFO - PROGRESS: at sentence #1080000, processed 8336754 words, keeping 92669 word types
# INFO - PROGRESS: at sentence #1090000, processed 8410071 words, keeping 93266 word types
# INFO - PROGRESS: at sentence #1100000, processed 8482543 words, keeping 93757 word types
# INFO - PROGRESS: at sentence #1110000, processed 8554731 words, keeping 94192 word types
# INFO - PROGRESS: at sentence #1120000, processed 8627007 words, keeping 94588 word types
# INFO - PROGRESS: at sentence #1130000, processed 8700988 words, keeping 94979 word types
# INFO - PROGRESS: at sentence #1140000, processed 8774480 words, keeping 95305 word types
# INFO - PROGRESS: at sentence #1150000, processed 8847784 words, keeping 95875 word types
# INFO - PROGRESS: at sentence #1160000, processed 8922314 words, keeping 96285 word types
# INFO - PROGRESS: at sentence #1170000, processed 8995903 words, keeping 96703 word types
# INFO - PROGRESS: at sentence #1180000, processed 9069901 words, keeping 96980 word types
# INFO - PROGRESS: at sentence #1190000, processed 9142252 words, keeping 97307 word types
# INFO - PROGRESS: at sentence #1200000, processed 9215563 words, keeping 97714 word types
# INFO - PROGRESS: at sentence #1210000, processed 9287519 words, keeping 98178 word types
# INFO - PROGRESS: at sentence #1220000, processed 9360695 words, keeping 98661 word types
# INFO - PROGRESS: at sentence #1230000, processed 9433111 words, keeping 99061 word types
# INFO - PROGRESS: at sentence #1240000, processed 9507290 words, keeping 99378 word types
# INFO - PROGRESS: at sentence #1250000, processed 9578655 words, keeping 99795 word types
# INFO - PROGRESS: at sentence #1260000, processed 9650369 words, keeping 100262 word types
# INFO - PROGRESS: at sentence #1270000, processed 9721272 words, keeping 100687 word types
# INFO - PROGRESS: at sentence #1280000, processed 9796345 words, keeping 101096 word types
# INFO - PROGRESS: at sentence #1290000, processed 9866875 words, keeping 101494 word types
# INFO - PROGRESS: at sentence #1300000, processed 9938169 words, keeping 101880 word types
# INFO - PROGRESS: at sentence #1310000, processed 10009493 words, keeping 102293 word types
# INFO - PROGRESS: at sentence #1320000, processed 10084654 words, keeping 102551 word types
# INFO - PROGRESS: at sentence #1330000, processed 10156724 words, keeping 103003 word types
# INFO - PROGRESS: at sentence #1340000, processed 10230228 words, keeping 103376 word types
# INFO - PROGRESS: at sentence #1350000, processed 10303275 words, keeping 103715 word types
# INFO - PROGRESS: at sentence #1360000, processed 10379829 words, keeping 104147 word types
# INFO - PROGRESS: at sentence #1370000, processed 10451923 words, keeping 104593 word types
# INFO - PROGRESS: at sentence #1380000, processed 10523921 words, keeping 104880 word types
# INFO - PROGRESS: at sentence #1390000, processed 10595607 words, keeping 105131 word types
# INFO - PROGRESS: at sentence #1400000, processed 10670389 words, keeping 105530 word types
# INFO - PROGRESS: at sentence #1410000, processed 10743389 words, keeping 105857 word types
# INFO - PROGRESS: at sentence #1420000, processed 10814763 words, keeping 106199 word types
# INFO - PROGRESS: at sentence #1430000, processed 10887457 words, keeping 106680 word types
# INFO - PROGRESS: at sentence #1440000, processed 10959492 words, keeping 107192 word types
# INFO - PROGRESS: at sentence #1450000, processed 11032556 words, keeping 107493 word types
# INFO - PROGRESS: at sentence #1460000, processed 11104945 words, keeping 107797 word types
# INFO - PROGRESS: at sentence #1470000, processed 11177012 words, keeping 108116 word types
# INFO - PROGRESS: at sentence #1480000, processed 11247662 words, keeping 108364 word types
# INFO - PROGRESS: at sentence #1490000, processed 11319461 words, keeping 108655 word types
# INFO - PROGRESS: at sentence #1500000, processed 11389665 words, keeping 109084 word types
# INFO - PROGRESS: at sentence #1510000, processed 11462104 words, keeping 109452 word types
# INFO - PROGRESS: at sentence #1520000, processed 11535935 words, keeping 109869 word types
# INFO - PROGRESS: at sentence #1530000, processed 11609460 words, keeping 110283 word types
# INFO - PROGRESS: at sentence #1540000, processed 11684781 words, keeping 110841 word types
# INFO - PROGRESS: at sentence #1550000, processed 11757750 words, keeping 111163 word types
# INFO - PROGRESS: at sentence #1560000, processed 11828999 words, keeping 111383 word types
# INFO - PROGRESS: at sentence #1570000, processed 11899834 words, keeping 111751 word types
# INFO - PROGRESS: at sentence #1580000, processed 11972783 words, keeping 112089 word types
# INFO - PROGRESS: at sentence #1590000, processed 12043408 words, keeping 112381 word types
# INFO - PROGRESS: at sentence #1600000, processed 12113969 words, keeping 112732 word types
# INFO - PROGRESS: at sentence #1610000, processed 12188542 words, keeping 113136 word types
# INFO - PROGRESS: at sentence #1620000, processed 12259122 words, keeping 113474 word types
# INFO - PROGRESS: at sentence #1630000, processed 12328818 words, keeping 113802 word types
# INFO - PROGRESS: at sentence #1640000, processed 12402451 words, keeping 114151 word types
# INFO - PROGRESS: at sentence #1650000, processed 12474430 words, keeping 114509 word types
# INFO - PROGRESS: at sentence #1660000, processed 12546491 words, keeping 115148 word types
# INFO - PROGRESS: at sentence #1670000, processed 12618206 words, keeping 115533 word types
# INFO - PROGRESS: at sentence #1680000, processed 12692790 words, keeping 115720 word types
# INFO - PROGRESS: at sentence #1690000, processed 12764004 words, keeping 116117 word types
# INFO - PROGRESS: at sentence #1700000, processed 12834802 words, keeping 116450 word types
# INFO - PROGRESS: at sentence #1710000, processed 12914166 words, keeping 116925 word types
# INFO - PROGRESS: at sentence #1720000, processed 12989762 words, keeping 117435 word types
# INFO - PROGRESS: at sentence #1730000, processed 13060720 words, keeping 117754 word types
# INFO - PROGRESS: at sentence #1740000, processed 13132280 words, keeping 118073 word types
# INFO - PROGRESS: at sentence #1750000, processed 13205794 words, keeping 118405 word types
# INFO - PROGRESS: at sentence #1760000, processed 13278608 words, keeping 118666 word types
# INFO - PROGRESS: at sentence #1770000, processed 13351391 words, keeping 118863 word types
# INFO - PROGRESS: at sentence #1780000, processed 13424573 words, keeping 119326 word types
# INFO - PROGRESS: at sentence #2920000, processed 21635278 words, keeping 150290 word types
# INFO - PROGRESS: at sentence #2930000, processed 21706816 words, keeping 150640 word types
# INFO - PROGRESS: at sentence #2940000, processed 21776245 words, keeping 150982 word types
# INFO - PROGRESS: at sentence #2950000, processed 21849038 words, keeping 151209 word types
# INFO - PROGRESS: at sentence #2960000, processed 21920078 words, keeping 151380 word types
# INFO - PROGRESS: at sentence #2970000, processed 21992040 words, keeping 151704 word types
# INFO - PROGRESS: at sentence #2980000, processed 22063621 words, keeping 152034 word types
# INFO - PROGRESS: at sentence #2990000, processed 22136841 words, keeping 152345 word types
# INFO - PROGRESS: at sentence #3000000, processed 22208273 words, keeping 152596 word types
# INFO - PROGRESS: at sentence #3010000, processed 22279926 words, keeping 152927 word types
# INFO - PROGRESS: at sentence #3020000, processed 22351267 words, keeping 153071 word types
# INFO - PROGRESS: at sentence #3030000, processed 22421414 words, keeping 153222 word types
# INFO - PROGRESS: at sentence #3040000, processed 22491585 words, keeping 153377 word types
# INFO - PROGRESS: at sentence #3050000, processed 22562190 words, keeping 153656 word types
# INFO - PROGRESS: at sentence #3060000, processed 22634888 words, keeping 153928 word types
# INFO - PROGRESS: at sentence #3070000, processed 22705084 words, keeping 154135 word types
# INFO - PROGRESS: at sentence #3080000, processed 22782105 words, keeping 154285 word types
# INFO - PROGRESS: at sentence #3090000, processed 22853506 words, keeping 154506 word types
# INFO - PROGRESS: at sentence #3100000, processed 22928011 words, keeping 154720 word types
# INFO - PROGRESS: at sentence #3110000, processed 22999660 words, keeping 154896 word types
# INFO - PROGRESS: at sentence #3120000, processed 23074130 words, keeping 155111 word types
# INFO - PROGRESS: at sentence #3130000, processed 23147519 words, keeping 155359 word types
# INFO - PROGRESS: at sentence #3140000, processed 23217664 words, keeping 155561 word types
# INFO - PROGRESS: at sentence #3150000, processed 23290660 words, keeping 155817 word types
# INFO - PROGRESS: at sentence #3160000, processed 23362495 words, keeping 156083 word types
# INFO - PROGRESS: at sentence #3170000, processed 23433439 words, keeping 156269 word types
# INFO - PROGRESS: at sentence #3180000, processed 23503351 words, keeping 156432 word types
# INFO - PROGRESS: at sentence #3190000, processed 23575564 words, keeping 156669 word types
# INFO - PROGRESS: at sentence #3200000, processed 23645856 words, keeping 156933 word types
# INFO - PROGRESS: at sentence #3210000, processed 23718883 words, keeping 157174 word types
# INFO - PROGRESS: at sentence #3220000, processed 23790698 words, keeping 157416 word types
# INFO - PROGRESS: at sentence #3230000, processed 23862279 words, keeping 157732 word types
# INFO - PROGRESS: at sentence #3240000, processed 23935486 words, keeping 157971 word types
# INFO - PROGRESS: at sentence #3250000, processed 24006303 words, keeping 158256 word types
# INFO - PROGRESS: at sentence #3260000, processed 24074888 words, keeping 158473 word types
# INFO - PROGRESS: at sentence #3270000, processed 24147386 words, keeping 158647 word types
# INFO - PROGRESS: at sentence #3280000, processed 24219478 words, keeping 158913 word types
# INFO - PROGRESS: at sentence #3290000, processed 24290952 words, keeping 159127 word types
# INFO - PROGRESS: at sentence #3300000, processed 24364586 words, keeping 159301 word types
# INFO - PROGRESS: at sentence #3310000, processed 24435669 words, keeping 159610 word types
# INFO - PROGRESS: at sentence #3320000, processed 24507056 words, keeping 159847 word types
# INFO - PROGRESS: at sentence #3330000, processed 24582762 words, keeping 160197 word types
# INFO - PROGRESS: at sentence #3340000, processed 24655371 words, keeping 160461 word types
# INFO - PROGRESS: at sentence #3350000, processed 24727019 words, keeping 160680 word types
# INFO - PROGRESS: at sentence #3360000, processed 24796034 words, keeping 160828 word types
# INFO - PROGRESS: at sentence #3370000, processed 24864287 words, keeping 161167 word types
# INFO - PROGRESS: at sentence #3380000, processed 24934174 words, keeping 161470 word types
# INFO - PROGRESS: at sentence #3390000, processed 25006995 words, keeping 161745 word types
# INFO - PROGRESS: at sentence #3400000, processed 25080670 words, keeping 162002 word types
# INFO - PROGRESS: at sentence #3410000, processed 25150030 words, keeping 162194 word types
# INFO - PROGRESS: at sentence #3420000, processed 25222099 words, keeping 162393 word types
# INFO - PROGRESS: at sentence #3430000, processed 25289378 words, keeping 162549 word types
# INFO - PROGRESS: at sentence #3440000, processed 25362094 words, keeping 162772 word types
# INFO - PROGRESS: at sentence #3450000, processed 25433779 words, keeping 163076 word types
# INFO - collected 163131 word types from a corpus of 25458317 raw words and 3453531 sentences
# INFO - Creating a fresh vocabulary
# INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=8 retains 35266 unique words (21.62% of original 163131, drops 127865)', 'datetime': '2023-10-12T01:24:36.331070', 'gensim': '4.3.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# INFO - Word2Vec lifecycle event {'msg': 'effective_min_count=8 leaves 25220959 word corpus (99.07% of original 25458317, drops 237358)', 'datetime': '2023-10-12T01:24:36.346693', 'gensim': '4.3.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# INFO - deleting the raw counts dictionary of 163131 items
# INFO - sample=0.001 downsamples 47 most-common words
# INFO - Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 23030323.30691146 word corpus (91.3%% of prior 25220959)', 'datetime': '2023-10-12T01:24:36.670373', 'gensim': '4.3.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# INFO - estimated required memory for 35266 words and 300 dimensions: 102271400 bytes
# INFO - resetting layer weights
# INFO - Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2023-10-12T01:24:37.391856', 'gensim': '4.3.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'build_vocab'}
# INFO - Word2Vec lifecycle event {'msg': 'training model with 3 workers on 35266 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2023-10-12T01:24:37.391856', 'gensim': '4.3.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# INFO - EPOCH 0 - PROGRESS: at 2.41% examples, 615548 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 0 - PROGRESS: at 4.80% examples, 635749 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 0 - PROGRESS: at 6.99% examples, 636801 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 0 - PROGRESS: at 9.09% examples, 628887 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 0 - PROGRESS: at 11.32% examples, 626789 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 0 - PROGRESS: at 13.93% examples, 621993 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 0 - PROGRESS: at 16.58% examples, 616014 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH
words/s, in_qsize 6, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 23.52% examples, 488579 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 25.79% examples, 489827 words/s, in_qsize 6, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 28.06% examples, 490616 words/s, in_qsize 6, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 30.38% examples, 491879 words/s, in_qsize 6, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 32.58% examples, 491689 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 34.55% examples, 488176 words/s, in_qsize 6, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 36.59% examples, 486437 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 38.82% examples, 486834 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 41.12% examples, 487707 words/s, in_qsize 4, out_qsize 1
# INFO - EPOCH 14 - PROGRESS: at 43.45% examples, 488885 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 45.67% examples, 489424 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 47.97% examples, 489982 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 50.23% examples, 490410 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 52.54% examples, 491497 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 54.71% examples, 491044 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 57.06% examples, 492056 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 59.38% examples, 492825 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 61.72% examples, 493393 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 64.34% examples, 496100 words/s, in_qsize 6, out_qsize 1
# INFO - EPOCH 14 - PROGRESS: at 67.15% examples, 499958 words/s, in_qsize 4, out_qsize 1
# INFO - EPOCH 14 - PROGRESS: at 69.77% examples, 502274 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 72.02% examples, 501987 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 74.52% examples, 503376 words/s, in_qsize 4, out_qsize 1
# INFO - EPOCH 14 - PROGRESS: at 77.30% examples, 506594 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 79.96% examples, 508848 words/s, in_qsize 6, out_qsize 1
# INFO - EPOCH 14 - PROGRESS: at 82.69% examples, 511518 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 85.46% examples, 514084 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 88.26% examples, 516668 words/s, in_qsize 4, out_qsize 1
# INFO - EPOCH 14 - PROGRESS: at 91.00% examples, 518916 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 93.83% examples, 521431 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 96.60% examples, 523634 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14 - PROGRESS: at 99.43% examples, 525550 words/s, in_qsize 5, out_qsize 0
# INFO - EPOCH 14: training on 25458317 raw words (23031467 effective words) took 43.8s, 526186 effective words/s
# INFO - Word2Vec lifecycle event {'msg': 'training on 381874755 raw words (345458277 effective words) took 584.2s, 591326 effective words/s', 'datetime': '2023-10-12T01:34:21.608074', 'gensim': '4.3.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# INFO - Word2Vec lifecycle event {'params': 'Word2Vec<vocab=35266, vector_size=300, alpha=0.025>', 'datetime': '2023-10-12T01:34:21.608074', 'gensim': '4.3.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# INFO - Word2Vec lifecycle event {'fname_or_handle': 'word2vec.model', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2023-10-12T01:34:21.623023', 'gensim': '4.3.2', 'python': '3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'saving'}
# INFO - storing np array 'vectors' to word2vec.model.wv.vectors.npy
# INFO - storing np array 'syn1neg' to word2vec.model.syn1neg.npy
# INFO - not storing attribute cum_table
# INFO - saved word2vec.model
